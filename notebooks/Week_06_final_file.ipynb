# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tabulate
import math
import numpy as np
import statsmodels.api as sm
from scipy import stats
import pingouin as pg
from scipy.stats import shapiro, pearsonr, spearmanr

# %%
#from github
username = "StefanFSmid"
repository = "ASDA_2025_Group_3_Porfolio"
directory = "additional_material/clean_inflation_df.csv"
github_url = f"https://raw.githubusercontent.com/{username}/{repository}/main/{directory}"
wb_df = pd.read_csv(github_url)

# %%
#print the WB data frame shape
print("World Bank DataFrame Shape:", wb_df.shape)
# Out:
# World Bank DataFrame Shape: (12924, 25)

# %%
#check column names
print("World Bank DataFrame Columns:", wb_df.columns.tolist())
# Out:
# World Bank DataFrame Columns: ['country', 'code', 'region', 'income_group', 'lending_category', 'year', 'agricultural_land_pct', 'forest_land_pct', 'control_of_corruption_estimate', 'access_to_electricity_pct', 'renewable_energy_consumption_pct', 'co2_emissions', 'pop_density', 'inflation_yr_pct', 'tax_revenue_pct', 'gov_effectiveness_estimate', 'gdp_current_usd_M', 'political_stability_estimate', 'rule_of_law_estimate', 'gov_exp_on_education_pct', 'gov_health_exp_pct', 'life_expectancy_at_birth', 'pop_M', 'voice_and_accountability_estimate', 'co2_per_capita_t']

# %% [markdown]
# # Control of Corruption vs Government Effectiveness

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # 1 row, 2 columns

sns.histplot(wb_df['control_of_corruption_estimate'], kde=True, ax=axes[0], color='skyblue')
axes[0].set_title('Control of Corruption')

sns.histplot(wb_df['gov_effectiveness_estimate'], kde=True, ax=axes[1], color='salmon')
axes[1].set_title('Government Effectiveness')

plt.tight_layout()
plt.show()

# %%
stats.shapiro(wb_df["control_of_corruption_estimate"])
# Out:
# c:\Users\sassa\miniconda3\envs\ASDA\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 12924.
#   res = hypotest_fun_out(*samples, **kwds)
# ShapiroResult(statistic=0.9572722611622734, pvalue=2.071059973782853e-51)

# %%
#now with penguin
pg.normality(wb_df["control_of_corruption_estimate"])
# Out:
#                                        W          pval  normal
# control_of_corruption_estimate  0.957272  2.071060e-51   False

# %%
stats.shapiro(wb_df["gov_effectiveness_estimate"])
# Out:
# c:\Users\sassa\miniconda3\envs\ASDA\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 12924.
#   res = hypotest_fun_out(*samples, **kwds)
# ShapiroResult(statistic=0.9754091794671199, pvalue=4.015538346958148e-42)

# %%
#now with penguin
pg.normality(wb_df["gov_effectiveness_estimate"])
# Out:
#                                    W          pval  normal
# gov_effectiveness_estimate  0.975409  4.015538e-42   False

# %%
#natural log transformation
corruption_log = np.log(wb_df["control_of_corruption_estimate"]+3)
gov_effectiveness_log = np.log(wb_df["gov_effectiveness_estimate"]+3)

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Plot 1
sns.histplot(wb_df["control_of_corruption_estimate"], ax=axes[0,0])
axes[0,0].set_title("no transformation")

# Plot 2 (natural log)
sns.histplot(corruption_log, ax=axes[0,1])
axes[0,1].set_title("transformed with natural log")

# Plot 3
sns.histplot(wb_df["gov_effectiveness_estimate"], ax=axes[1,0])
axes[1,0].set_title("no transformation")

# Plot 3 (natural log)
sns.histplot(gov_effectiveness_log, ax=axes[1,1])
axes[1,1].set_title("transformed with natural log")

plt.tight_layout()
plt.show()

# %%
pg.normality(corruption_log)
# Out:
#                                        W          pval  normal
# control_of_corruption_estimate  0.983884  1.151299e-35   False

# %%
pg.normality(gov_effectiveness_log)
# Out:
#                                    W          pval  normal
# gov_effectiveness_estimate  0.968204  2.529666e-46   False

# %%
x = wb_df['control_of_corruption_estimate']
y = wb_df['gov_effectiveness_estimate']

# %%
# Spearman correlation
r_spearman, p_spearman = spearmanr(x, y)
print(f'Spearman correlation: rho = {r_spearman:.3f}, p-value < 1e-10')

# Scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(x=x, y=y, alpha=0.6, s=20)
plt.xlabel('Control of Corruption')
plt.ylabel('Government Effectiveness')
plt.title(f'Correlation between Control of Corruption and Government Effectiveness')
plt.show()
# Out:
# Spearman correlation: rho = 0.918, p-value < 1e-10

# %%
# Define the order
income_order = ['Low income', 'Lower middle income', 'Upper middle income', 'High income']

# Convert to categorical with order
wb_df['income_group'] = pd.Categorical(wb_df['income_group'], categories=income_order, ordered=True)

plt.figure(figsize=(10,6))
sns.scatterplot(
    data=wb_df,
    x= x, 
    y= y, 
    hue='income_group', 
    palette='Set1', 
    s=20
)
plt.xlabel('Control of Corruption')
plt.ylabel('Government Effectiveness')
plt.title('Control of Corruption vs Government Effectiveness by Income Group')
plt.legend(title='Income Group')
plt.show()

# %%
# Create 2x2 subplot
fig, axes = plt.subplots(2, 2, figsize=(12,10))

# 1. Low income
df = wb_df[wb_df['income_group'] == 'Low income']
sns.scatterplot(x=x[df.index], y=y[df.index], s=20, ax=axes[0,0])
rho, _ = spearmanr(x[df.index], y[df.index])
axes[0,0].set_title(f"Low income\nSpearman rho = {rho:.2f}")
axes[0,0].set_xlabel('Control of Corruption')
axes[0,0].set_ylabel('Government Effectiveness')

# 2. Lower middle income
df = wb_df[wb_df['income_group'] == 'Lower middle income']
sns.scatterplot(x=x[df.index], y=y[df.index], s=20, ax=axes[0,1])
rho, _ = spearmanr(x[df.index], y[df.index])
axes[0,1].set_title(f"Lower middle income\nSpearman rho = {rho:.2f}")
axes[0,1].set_xlabel('Control of Corruption')
axes[0,1].set_ylabel('')

# 3. Upper middle income
df = wb_df[wb_df['income_group'] == 'Upper middle income']
sns.scatterplot(x=x[df.index], y=y[df.index], s=20, ax=axes[1,0])
rho, _ = spearmanr(x[df.index], y[df.index])
axes[1,0].set_title(f"Upper middle income\nSpearman rho = {rho:.2f}")
axes[1,0].set_xlabel('Control of Corruption')
axes[1,0].set_ylabel('Government Effectiveness')

# 4. High income
df = wb_df[wb_df['income_group'] == 'High income']
sns.scatterplot(x=x[df.index], y=y[df.index], s=20, ax=axes[1,1])
rho, _ = spearmanr(x[df.index], y[df.index])
axes[1,1].set_title(f"High income\nSpearman rho = {rho:.2f}")
axes[1,1].set_xlabel('Control of Corruption')
axes[1,1].set_ylabel('')

plt.tight_layout()
plt.show()

# %%
# Step 1: create an empty list to store results
corr_list = []

# Step 2: loop through each country
for country in wb_df["country"].unique():
    # Filter data for the country and years 2000–2024
    df = wb_df[(wb_df["country"] == country) &
               (wb_df["year"] >= 2000) &
               (wb_df["year"] <= 2024)]
    
    # Only compute if we have at least 4 years of data
    if len(df) > 3:
        corr = df["control_of_corruption_estimate"].corr(df["gov_effectiveness_estimate"], method="spearman")
        region = df["region"].values[0]
        corr_list.append([country, region, corr])

# Step 3: convert list to DataFrame
corr_df = pd.DataFrame(corr_list, columns=["country", "region", "correlation"])

# Step 4: pick top 5 correlations (highest values)
top5 = corr_df.sort_values(by="correlation", ascending=False).head(5)

# Step 5: pick bottom 5 correlations (closest to 0)
# We'll use absolute value for "closeness to 0"
corr_df["abs_corr"] = corr_df["correlation"].abs()
bottom5 = corr_df.sort_values(by="abs_corr").head(5)

print("Top 5 correlated countries:")
print(top5[["country", "region", "correlation"]])

print("\nBottom 5 countries with correlation closest to 0:")
print(bottom5[["country", "region", "correlation"]])
# Out:
# Top 5 correlated countries:
#            country                                             region  \
# 71       Greenland                              Europe & Central Asia
# 201    Yemen, Rep.  Middle East, North Africa, Afghanistan & Pakistan
# 58         Eritrea                                 Sub-Saharan Africa
# 129          Nauru                                East Asia & Pacific
# 45   Cote d'Ivoire                                 Sub-Saharan Africa
#
#      correlation
# 71      0.953782
# 201     0.947265
# 58      0.942714
# 129     0.941895
# 45      0.938919
#
# Bottom 5 countries with correlation closest to 0:
#            country                 region  correlation
# 106  Liechtenstein  Europe & Central Asia    -0.007417
# 195     Uzbekistan  Europe & Central Asia     0.009366
# 89           Italy  Europe & Central Asia     0.009387
# 176    Switzerland  Europe & Central Asia     0.010936
# 180       Thailand    East Asia & Pacific     0.026119

# %%
# List of countries
countries = ["Yemen, Rep.", "Thailand"]

# Filter the data
df_selected = wb_df[(wb_df["country"].isin(countries)) & 
                    (wb_df["year"] >= 2000) & (wb_df["year"] <= 2024)]

# Select relevant columns
df_table = df_selected[["country", "year", "control_of_corruption_estimate", "gov_effectiveness_estimate"]]

# Sort by country and year
df_table = df_table.sort_values(["country", "year"]).reset_index(drop=True)

# Display the table
print(df_table)
# Out:
#         country  year  control_of_corruption_estimate  \
# 0      Thailand  2000                           -0.23
# 1      Thailand  2001                           -0.40
# 2      Thailand  2002                           -0.34
# 3      Thailand  2003                           -0.20
# 4      Thailand  2004                           -0.25
# 5      Thailand  2005                           -0.21
# 6      Thailand  2006                           -0.41
# 7      Thailand  2007                           -0.40
# 8      Thailand  2008                           -0.44
# 9      Thailand  2009                           -0.33
# 10     Thailand  2010                           -0.36
# 11     Thailand  2011                           -0.35
# 12     Thailand  2012                           -0.40
# 13     Thailand  2013                           -0.37
# 14     Thailand  2014                           -0.48
# 15     Thailand  2015                           -0.56
# ...

# %%
plt.figure(figsize=(14, 10))  # 2 rows × 2 columns

# --- Yemen ---
df_yemen = wb_df[(wb_df["country"] == "Yemen, Rep.") & 
                 (wb_df["year"] >= 2000) & (wb_df["year"] <= 2024)].sort_values("year")

# Scatter plot
plt.subplot(2, 2, 1)
sns.regplot(
    data=df_yemen,
    x="control_of_corruption_estimate",
    y="gov_effectiveness_estimate",
    scatter_kws={"s":40},
    ci=None
)
corr_yemen = df_yemen["control_of_corruption_estimate"].corr(df_yemen["gov_effectiveness_estimate"], method='spearman')
plt.title(f"Yemen Scatter\nSpearman Corr = {corr_yemen:.2f}")
plt.xlabel("Control of Corruption")
plt.ylabel("Government Effectiveness")
plt.grid(True)

# Line plot
plt.subplot(2, 2, 3)
plt.plot(df_yemen["year"], df_yemen["control_of_corruption_estimate"], marker='o', label="Control of Corruption")
plt.plot(df_yemen["year"], df_yemen["gov_effectiveness_estimate"], marker='s', label="Government Effectiveness")
plt.title("Yemen Trend Over Years")
plt.xlabel("Year")
plt.ylabel("Estimate")
plt.legend()
plt.grid(True)

# --- Thailand ---
df_thailand = wb_df[(wb_df["country"] == "Thailand") & 
                       (wb_df["year"] >= 2000) & (wb_df["year"] <= 2024)].sort_values("year")

# Scatter plot
plt.subplot(2, 2, 2)
sns.regplot(
    data=df_thailand,
    x="control_of_corruption_estimate",
    y="gov_effectiveness_estimate",
    scatter_kws={"s":40},
    ci=None
)
corr_thailand = df_thailand["control_of_corruption_estimate"].corr(df_thailand["gov_effectiveness_estimate"], method='spearman')
plt.title(f"Thailand Scatter\nSpearman Corr = {corr_thailand:.2f}")
plt.xlabel("Control of Corruption")
plt.ylabel("Government Effectiveness")
plt.grid(True)

# Line plot
plt.subplot(2, 2, 4)
plt.plot(df_thailand["year"], df_thailand["control_of_corruption_estimate"], marker='o', label="Control of Corruption")
plt.plot(df_thailand["year"], df_thailand["gov_effectiveness_estimate"], marker='s', label="Government Effectiveness")
plt.title("Thailand Trend Over Years")
plt.xlabel("Year")
plt.ylabel("Estimate")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Pre-2008
df_pre2008 = wb_df[wb_df['year'] < 2008]

# Post-2008
df_post2008 = wb_df[wb_df['year'] >= 2008]

# %%
# Spearman correlations
rho_pre, p_pre = spearmanr(df_pre2008['control_of_corruption_estimate'],
                           df_pre2008['gov_effectiveness_estimate'])
rho_post, p_post = spearmanr(df_post2008['control_of_corruption_estimate'],
                             df_post2008['gov_effectiveness_estimate'])
print(f"Pre-2008: Spearman rho = {rho_pre:.2f}, p = {p_pre:.3e}")
print(f"Post-2008: Spearman rho = {rho_post:.2f}, p = {p_post:.3e}")
fig, axes = plt.subplots(1, 2, figsize=(14,6))

sns.scatterplot(x=df_pre2008['control_of_corruption_estimate'],
                y=df_pre2008['gov_effectiveness_estimate'],
                s=20, alpha=0.6, ax=axes[0])
axes[0].set_title(f"Pre-2008\nSpearman rho = {rho_pre:.2f}")
axes[0].set_xlabel('Control of Corruption')
axes[0].set_ylabel('Government Effectiveness')

sns.scatterplot(x=df_post2008['control_of_corruption_estimate'],
                y=df_post2008['gov_effectiveness_estimate'],
                s=20, alpha=0.6, ax=axes[1])
axes[1].set_title(f"Post-2008\nSpearman rho = {rho_post:.2f}")
axes[1].set_xlabel('Control of Corruption')
axes[1].set_ylabel('')

plt.tight_layout()
plt.show()
# Out:
# Pre-2008: Spearman rho = 0.92, p = 0.000e+00
# Post-2008: Spearman rho = 0.91, p = 0.000e+00

# %% [markdown]
# # Political_Stability vs Inflation

# %% [markdown]
# ### Direct Relationship

# %%
#Histogram
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

sns.histplot(wb_df["political_stability_estimate"], color="green", ax=axes[0])
axes[0].set_title("distribution of political stability")

sns.histplot(wb_df["inflation_yr_pct"], color="orange", ax=axes[1])
axes[1].set_title("distribution of inflation")

plt.show()

# %%
#Checking normality
print(pg.normality(wb_df["political_stability_estimate"]))
print(pg.normality(wb_df["inflation_yr_pct"]))
# Out:
#                                      W          pval  normal
# political_stability_estimate  0.961371  1.213685e-49   False
#                          W           pval  normal
# inflation_yr_pct  0.374791  3.680161e-110   False

# %%
wb_df["political_stability_log"] = np.log1p(wb_df["political_stability_estimate"].clip(lower=0))
wb_df["inflation_log"] = np.log1p(wb_df["inflation_yr_pct"].clip(lower=0))

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# 1. Original political stability
sns.histplot(wb_df["political_stability_estimate"], ax=axes[0, 0], color="green")
axes[0, 0].set_title("Political Stability (Original)")
axes[0, 0].set_xlabel("political_stability_estimate")

# 2. Original inflation
sns.histplot(wb_df["inflation_yr_pct"], ax=axes[0, 1], color="orange")
axes[0, 1].set_title("Inflation % (Original)")
axes[0, 1].set_xlabel("inflation_yr_pct")

# 3. Log1p political stability
sns.histplot(wb_df["political_stability_log"], ax=axes[1, 0], color="blue")
axes[1, 0].set_title("Political Stability (log)")
axes[1, 0].set_xlabel("log(political_stability_estimate)")

# 4. Log1p inflation
sns.histplot(wb_df["inflation_log"], ax=axes[1, 1], color="red")
axes[1, 1].set_title("Inflation % (log)")
axes[1, 1].set_xlabel("log(inflation_yr_pct)")

plt.tight_layout()

# %%
#Normality after log transformation
print(pg.normality(wb_df["political_stability_log"]))
print(pg.normality(wb_df["inflation_log"]))
# Out:
#                                 W          pval  normal
# political_stability_log  0.787636  8.543196e-84   False
#                      W          pval  normal
# inflation_log  0.97421  6.956017e-43   False

# %%
sns.scatterplot(data=wb_df, x="political_stability_log", y="inflation_log")
plt.title("Correlation between political_stability and inflation")
plt.show()

# %%
sns.scatterplot(data=wb_df, x="political_stability_estimate", y="inflation_yr_pct")
plt.title("Correlation between political_stability and inflation")
plt.show()

# %%
#Remove outlier in Inflation
new_df = wb_df.copy()
condition = wb_df["inflation_yr_pct"] <= 40
new_df = new_df.loc[condition]

# %%
#Correlation test with outliers (Spearman)
pg.corr(wb_df["political_stability_estimate"],wb_df["inflation_yr_pct"], method="spearman")
# Out:
#               n         r           CI95%  p-val  power
# spearman  12923 -0.329116  [-0.34, -0.31]    0.0    1.0

# %%
#Correlation test (Pearson)
pg.corr(new_df["political_stability_estimate"],new_df["inflation_yr_pct"], method="pearson")
# Out:
#              n         r           CI95%          p-val        BF10  power
# pearson  12612 -0.289355  [-0.31, -0.27]  9.083172e-242  2.762e+237    1.0

# %%
#Correlation test with outliers (Pearson)
pg.corr(wb_df["political_stability_estimate"],wb_df["inflation_yr_pct"], method="pearson")
# Out:
#              n         r           CI95%         p-val       BF10  power
# pearson  12923 -0.167581  [-0.18, -0.15]  4.985176e-82  8.979e+77    1.0

# %% [markdown]
# ### Group Difference

# %%
#Correlation across Income Groups

groups = wb_df["income_group"].unique()

for g in groups:
    df_g = wb_df[wb_df["income_group"] == g]
    print(f"\nGroup: {g}")
    print(pg.corr(df_g["political_stability_estimate"],df_g["inflation_yr_pct"],method="spearman"))
# Out:
# Group: Low income
#              n         r          CI95%         p-val     power
# spearman  1625 -0.156138  [-0.2, -0.11]  2.481279e-10  0.999994
#
# Group: Upper middle income
#              n         r          CI95%         p-val  power
# spearman  3408 -0.236739  [-0.27, -0.2]  1.262606e-44    1.0
#
# Group: High income
#              n         r           CI95%         p-val  power
# spearman  4713 -0.144201  [-0.17, -0.12]  2.546611e-23    1.0
#
# Group: Lower middle income
#              n         r          CI95%         p-val  power
# spearman  3177 -0.131903  [-0.17, -0.1]  8.369348e-14    1.0

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.scatterplot(
    data=wb_df, 
    x="political_stability_estimate", 
    y="inflation_yr_pct",
    ax=axes[0]
)
axes[0].set_title("Political Stability vs Inflation")

sns.scatterplot(
    data=wb_df,
    x='political_stability_estimate',
    y='inflation_yr_pct',
    hue='income_group',
    ax=axes[1]
)
axes[1].set_title("Political Stability vs Inflation by Income Group")

plt.tight_layout()
plt.show()

# %%
regions = new_df["region"].unique()

for r in regions:
    df_r = new_df[new_df["region"] == r]
    print(f"\nregions: {r}")
    print(pg.corr(df_r["political_stability_estimate"],df_r["inflation_yr_pct"],method="spearman"))
# Out:
# regions: Middle East, North Africa, Afghanistan & Pakistan
#              n         r           CI95%         p-val  power
# spearman  1435 -0.431551  [-0.47, -0.39]  3.625301e-66    1.0
#
# regions: Europe & Central Asia
#              n         r           CI95%         p-val  power
# spearman  3271 -0.305969  [-0.34, -0.27]  7.649319e-72    1.0
#
# regions: East Asia & Pacific
#              n         r           CI95%         p-val  power
# spearman  2152 -0.387603  [-0.42, -0.35]  4.384038e-78    1.0
#
# regions: Sub-Saharan Africa
#              n         r          CI95%     p-val     power
# spearman  2925 -0.060243  [-0.1, -0.02]  0.001115  0.903367
#
# regions: Latin America & Caribbean
#              n         r           CI95%         p-val  power
# spearman  2255 -0.387625  [-0.42, -0.35]  9.567842e-82    1.0
#
# regions: South Asia
#             n         r           CI95%     p-val     power
# spearman  382 -0.170857  [-0.27, -0.07]  0.000799  0.919724
#
# ...

# %%
regions = wb_df["region"].unique()
num_regions = len(regions)

# Choose subplot grid (auto layout: 3 columns)
cols = 3
rows = (num_regions + cols - 1) // cols

fig, axes = plt.subplots(rows, cols, figsize=(18, 12))
axes = axes.flatten()

for i, region in enumerate(regions):
    df_region = wb_df[wb_df["region"] == region]
    
    sns.scatterplot(
        data=df_region,
        x="political_stability_estimate",
        y="inflation_yr_pct",
        ax=axes[i],
    )
    
    axes[i].set_title(region)
    axes[i].set_xlabel("Political Stability")
    axes[i].set_ylabel("Inflation (%)")

# Hide unused axes (in case region count < rows*cols)
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Temporal Change

# %%
#Correlation before and after 2008 financial crisis    

pre = new_df[new_df["year"] < 2008]
print("Pre-2008:")
print(pg.corr(pre["political_stability_estimate"],pre["inflation_yr_pct"],method="spearman"))

post = new_df[new_df["year"] >= 2008]
print("\nPost-2008:")
print(pg.corr(post["political_stability_estimate"],post["inflation_yr_pct"],method="spearman"))
# Out:
# Pre-2008:
#              n         r          CI95%          p-val  power
# spearman  9386 -0.317805  [-0.34, -0.3]  2.840537e-219    1.0
#
# Post-2008:
#              n         r          CI95%          p-val  power
# spearman  3226 -0.370461  [-0.4, -0.34]  1.704479e-105    1.0

# %%
# Split data
pre = wb_df[wb_df["year"] < 2008]
post = wb_df[wb_df["year"] >= 2008]

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Pre-2008 scatter
sns.scatterplot(
    data=pre,
    x="political_stability_estimate",
    y="inflation_yr_pct",
    ax=axes[0]
)
axes[0].set_title("Pre-2008: Political Stability vs Inflation")
axes[0].set_xlabel("Political Stability Estimate")
axes[0].set_ylabel("Inflation (%)")

# Post-2008 scatter
sns.scatterplot(
    data=post,
    x="political_stability_estimate",
    y="inflation_yr_pct",
    ax=axes[1]
)
axes[1].set_title("Post-2008: Political Stability vs Inflation")
axes[1].set_xlabel("Political Stability Estimate")
axes[1].set_ylabel("")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Unexpected Patterns

# %%
max_inflation_row = wb_df.loc[wb_df["inflation_yr_pct"].idxmax()]
print(max_inflation_row[["country", "year", "inflation_yr_pct", "political_stability_estimate"]])
# Out:
# country                         Indonesia
# year                                 1965
# inflation_yr_pct                   306.76
# political_stability_estimate        -0.76
# Name: 5305, dtype: object

# %%
# Get top 10 rows with highest inflation
top10_inflation = wb_df.nlargest(10, "inflation_yr_pct")

# Display relevant information
print(top10_inflation[["country", "year", "inflation_yr_pct", "political_stability_estimate"]])
# Out:
#                 country  year  inflation_yr_pct  political_stability_estimate
# 5305          Indonesia  1965            306.76                         -0.76
# 351              Angola  1992            299.51                         -0.52
# 1112            Belarus  1999            293.68                          0.14
# 2679   Congo, Dem. Rep.  1999            284.89                         -2.15
# 1480            Bolivia  1986            276.34                         -0.37
# 1479            Bolivia  1983            275.59                         -0.37
# 7805           Mongolia  1993            268.15                          0.71
# 12920          Zimbabwe  2019            255.30                         -0.94
# 9520            Romania  1993            255.17                          0.19
# 354              Angola  1999            248.20                         -0.52

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=False)

# Indonesia
indonesia = wb_df[wb_df["country"] == "Indonesia"]
sns.lineplot(
    data=indonesia,
    x="year",
    y="inflation_yr_pct",
    marker="o",
    color="blue",
    ax=axes[0]
)
axes[0].set_title("Inflation Over Time - Indonesia")
axes[0].set_xlabel("Year")
axes[0].set_ylabel("Inflation (%)")
axes[0].grid(True)

# Mongolia
mongolia = wb_df[wb_df["country"] == "Mongolia"]
sns.lineplot(
    data=mongolia,
    x="year",
    y="inflation_yr_pct",
    marker="o",
    color="orange",
    ax=axes[1]
)
axes[1].set_title("Inflation Over Time - Mongolia")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Inflation (%)")
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
#Correlation when splitting political stability into bins

wb_df["stability_bin"] = pd.cut(
    wb_df["political_stability_estimate"],
    bins=4
)

for b in wb_df["stability_bin"].unique():
    df_b = wb_df[wb_df["stability_bin"] == b]
    print(f"\nBin: {b}")
    print(pg.corr(df_b["political_stability_estimate"],df_b["inflation_yr_pct"],method="spearman"))
# Out:
# Bin: (-3.315, -1.993]
#             n         r         CI95%     p-val     power
# spearman  535  0.199375  [0.12, 0.28]  0.000003  0.996586
#
# Bin: (-0.675, 0.642]
#              n         r           CI95%     p-val     power
# spearman  5578 -0.063504  [-0.09, -0.04]  0.000002  0.997351
#
# Bin: (-1.993, -0.675]
#              n         r          CI95%     p-val     power
# spearman  2523  0.011455  [-0.03, 0.05]  0.565206  0.088671
#
# Bin: (0.642, 1.96]
#              n         r           CI95%         p-val  power
# spearman  4287 -0.139057  [-0.17, -0.11]  5.874491e-20    1.0

# %% [markdown]
# ## The Story of Political Stability vs Inflation
#
# ### 1. Relationship between political Stability and Inflation
# This analysis investigates how political stability relates to inflation worldwide. Overall, there is a weak negative correlation (Spearman ρ ≈ −0.325), suggesting that countries with higher political stability tend to experience slightly lower inflation, though the relationship is not strong.
#
# ### 2.1. Differences Across Income Groups
# Examining correlations within income groups reveals that the relationship varies slightly across economic contexts:
# - Low-income countries: ρ ≈ −0.124 (n=1572), indicating a weak negative association.
# - Lower-middle-income countries: ρ ≈ −0.135 (n=3120), also weakly negative.
# - Upper-middle-income countries: ρ ≈ −0.214 (n=3293), slightly stronger negative correlation.
# - High-income countries: ρ ≈ −0.136 (n=4627), weakly negative.
#
# This shows that political stability’s link to inflation is generally negative across all income levels, with the effect slightly more pronounced in upper-middle-income nations.
#
# ### 2.2. Differences Across Regions
# Regional results show larger variation, some regions show a fairly strong negative association, others almost none:
# - Middle East, North Africa, Afghanistan & Pakistan: ρ ≈ −0.432 (n=1435) — relatively strong negative.
# - East Asia & Pacific: ρ ≈ −0.388 (n=2152) — strong negative.
# - Latin America & Caribbean: ρ ≈ −0.388 (n=2255) — strong negative.
# - Europe & Central Asia: ρ ≈ −0.306 (n=3271) — moderate negative.
# - South Asia: ρ ≈ −0.171 (n=382) — weak negative.
# - Sub-Saharan Africa: ρ ≈ −0.060 (n=2925) — very weak negative.
# - North America: ρ ≈ −0.086 (n=192) — very weak and not statistically significant (p ≈ 0.24).
#
# The stability–inflation link is strongest in regions like the Middle East & North Africa, East Asia & Pacific, and Latin America, and weakest in Sub-Saharan Africa and North America. Regional context matters.
#
# ### 3. Temporal Changes (Pre- vs Post-2008 Financial Crisis)
# To examine whether the relationship between political stability and inflation changed after the 2008 financial crisis, we split the data into pre-2008 and post-2008 periods. The correlation remained negative in both periods, indicating that more politically stable countries generally experienced lower inflation throughout. However, the strength of the relationship shifted slightly, reflecting how major economic shocks can influence the sensitivity of inflation to political conditions, with post-crisis dynamics potentially amplifying or dampening this link depending on the region and stability level.
#
# ### 4. Unexpected Patterns (Binning Political Stability)
# When political stability is divided into bins, a more nuanced pattern emerges:
# - Very unstable countries (−3.315 to −1.993): ρ ≈ +0.140, surprisingly showing a slight positive association.
# - Moderately unstable (−1.993 to −0.675): ρ ≈ +0.006, essentially no correlation.
# - Slightly stable to neutral (−0.675 to 0.642): ρ ≈ −0.067, weak negative.
# - Highly stable (0.642 to 1.96): ρ ≈ −0.133, weakly negative.
#
# This reveals that nonlinear patterns exist: in the least stable countries, inflation can sometimes increase with stability, while in more stable nations, the expected negative relationship dominates.

# %% [markdown]
# ## life expectancy at birth vs GDP

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# ## Research Question
#
# Does higher economic output (GDP) relate to higher life expectancy across countries, and does this relationship differ by income group and over time?

# %% [markdown]
# ## Data Inspection : Distributions & Outliers

# %%
# Histogram: Life Expectancy
gdp_clean = wb_df[wb_df["gdp_current_usd_M"] > 0]
gdp_log = np.log10(gdp_clean["gdp_current_usd_M"])

# Create side-by-side plots
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# 1) Life Expectancy Histogram
sns.histplot(wb_df["life_expectancy_at_birth"], kde=True, color="blue", ax=axes[0])
axes[0].set_title("Distribution of Life Expectancy at Birth")
axes[0].set_xlabel("Life Expectancy")
axes[0].set_ylabel("Count")

# 2) GDP (log) Histogram
sns.histplot(gdp_log, bins=40, color="green", ax=axes[1])
axes[1].set_title("Distribution of GDP (log10 scale)")
axes[1].set_xlabel("Log10 of GDP (Million USD)")
axes[1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# Boxplot: Life Expectancy
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# 1) Life Expectancy boxplot
plt.sca(axes[0])
sns.boxplot(y=wb_df["life_expectancy_at_birth"])
plt.title("Outliers in Life Expectancy")

# 2) GDP (log) boxplot
plt.sca(axes[1])
sns.boxplot(y=gdp_log)

plt.title("Outliers in GDP (log scale)")
plt.ylabel("Log10 GDP")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data Inspection
#
# The histogram of GDP shows a highly right-skewed distribution with some extreme values (very rich countries).
# Life expectancy is more normally distributed with fewer extreme outliers.
# Because of the skewness in GDP, we apply a log transformation to make the distribution more symmetric and the relationship with life expectancy more linear.
# We also remove rows with non-positive GDP before log transformation.

# %%
#Log Transformation (No warnings version)
# Keep only valid GDP values

wb_df = wb_df[wb_df["gdp_current_usd_M"] > 0].copy()

# Create log GDP
wb_df["gdp_log"] = np.log(wb_df["gdp_current_usd_M"])

sns.histplot(wb_df["gdp_log"], kde=True, color="purple")
plt.title("Distribution of log(GDP)")
plt.show()

# %%
# Scatterplot: Life Expectancy vs log(GDP)
sns.scatterplot(
    data=wb_df,
    x="gdp_log",
    y="life_expectancy_at_birth",
    alpha=0.5
)
plt.title("Life Expectancy vs log(GDP)")
plt.show()

# %%
#Scatter Plot by Income Group
sns.scatterplot(
    data=wb_df,
    x="gdp_log",
    y="life_expectancy_at_birth",
    hue="income_group",
    alpha=0.6
)
plt.title("Life Expectancy vs log(GDP) by Income Group")
plt.show()

# %% [markdown]
# ## Correlation Tests

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np

# 1. Clean the data first
corr_df = wb_df[[
    "gdp_current_usd_M",
    "life_expectancy_at_birth"
]].dropna()

# 2. Remove zero or negative GDP before log
corr_df = corr_df[corr_df["gdp_current_usd_M"] > 0]

# 3. Create log GDP
corr_df["gdp_log"] = np.log10(corr_df["gdp_current_usd_M"])

# 4. Assign variables
x = corr_df["gdp_log"]
y = corr_df["life_expectancy_at_birth"]

# 5. Run correlations
pearson_r, pearson_p = pearsonr(x, y)
spearman_r, spearman_p = spearmanr(x, y)

# 6. Print results
print("Pearson correlation:")
print("r =", round(pearson_r, 3), "p-value =", pearson_p)

print("\n Spearman correlation:")
print("rho =", round(spearman_r, 3), "p-value =", spearman_p)
# Out:
# Pearson correlation:
# r = 0.443 p-value = 0.0
#
#  Spearman correlation:
# rho = 0.471 p-value = 0.0

# %% [markdown]
# ## Analysis Report
# A moderate positive relationship was found between GDP and life expectancy. The Spearman correlation showed ρ = 0.471 (p < 0.001), indicating that countries with higher GDP tend to have higher life expectancy. While the association is statistically significant, the strength is moderate, suggesting that economic growth is an important but not the only factor influencing population health.
#
# This correlation does not imply causation, as other factors such as healthcare systems, education, and governance may influence life expectancy independent of economic output.

# %%
from scipy.stats import pearsonr, spearmanr

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

x = corr_df["gdp_log"]
y = corr_df["life_expectancy_at_birth"]

# 1) Scatter plot
axes[0].scatter(x, y, alpha=0.6)
axes[0].set_xlabel("log(GDP in million USD)")
axes[0].set_ylabel("Life Expectancy at Birth")
axes[0].set_title("Life Expectancy vs log(GDP)")

pearson_corr, pearson_p = pearsonr(x, y)
spearman_corr, spearman_p = spearmanr(x, y)

axes[0].text(
    0.05, 0.95,
    f"Pearson: {pearson_corr:.3f} (p={pearson_p:.3e})\nSpearman: {spearman_corr:.3f} (p={spearman_p:.3e})",
    transform=axes[0].transAxes,
    va="top",
    bbox=dict(boxstyle="round", facecolor="wheat", alpha=0.5)
)

# 2) Histogram of Y (life expectancy)
axes[1].hist(y, bins=20, edgecolor='black', alpha=0.7, color='orange')
axes[1].set_xlabel("Life Expectancy at Birth")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Distribution of Life Expectancy")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Statistical Test
#
# Computed both Pearson and Spearman correlations between log(GDP) and life expectancy.
# Pearson is appropriate here because we log-transformed GDP, which makes the relationship closer to linear and reduces skewness.
# Spearman is also reported as a robustness check because it is based on ranks and does not assume normality.

# %% [markdown]
# ## Group-Level Analysis (Income Groups)

# %%
# Average by income group
group_means = wb_df.groupby("income_group")[
    ["life_expectancy_at_birth", "gdp_current_usd_M"]
].mean().round(2)

print(group_means)

# Bar plot
sns.barplot(
    data=group_means.reset_index(),
    x="income_group",
    y="life_expectancy_at_birth"
)
plt.title("Average Life Expectancy by Income Group")
plt.xticks(rotation=20)
plt.show()

# Correlation within each income group
for g in wb_df["income_group"].dropna().unique():
    df_g = wb_df[wb_df["income_group"] == g]
    r, p = spearmanr(df_g["gdp_log"], df_g["life_expectancy_at_birth"])
    print(f"\nIncome group: {g}")
    print("Spearman rho:", round(r, 3), " | p-value:", p, " | n:", len(df_g))
# Out:
#                      life_expectancy_at_birth  gdp_current_usd_M
# income_group
# Low income                              50.05            8120.44
# Lower middle income                     58.06           35919.44
# Upper middle income                     65.94          132646.28
# High income                             73.31          335473.56
# Income group: Low income
# Spearman rho: 0.351  | p-value: 1.8674414125087072e-48  | n: 1625
#
# Income group: Upper middle income
# Spearman rho: 0.294  | p-value: 3.6941218469645013e-69  | n: 3408
#
# Income group: High income
# Spearman rho: 0.474  | p-value: 1.8471525846088494e-262  | n: 4713
#
# Income group: Lower middle income
# Spearman rho: 0.331  | p-value: 6.167599008881911e-82  | n: 3177

# %% [markdown]
# ## Temporal Analysis (Pre vs Post 2008)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

# 1) Make sure gdp_log exists and GDP > 0
wb_df = wb_df[wb_df["gdp_current_usd_M"] > 0].copy()
if "gdp_log" not in wb_df.columns:
    wb_df["gdp_log"] = np.log10(wb_df["gdp_current_usd_M"])

# 2) Split into pre- and post-2008
pre = wb_df[wb_df["year"] < 2008]
post = wb_df[wb_df["year"] >= 2008]

# 3) Compute Spearman correlations
print("Pre-2008:")
r_pre, p_pre = spearmanr(pre["gdp_log"], pre["life_expectancy_at_birth"])
print("rho:", round(r_pre, 3), "p-value:", p_pre, "n:", len(pre))

print("\nPost-2008:")
r_post, p_post = spearmanr(post["gdp_log"], post["life_expectancy_at_birth"])
print("rho:", round(r_post, 3), "p-value:", p_post, "n:", len(post))

# 4) Plot side-by-side scatterplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Pre-2008 scatter
axes[0].scatter(pre["gdp_log"], pre["life_expectancy_at_birth"], alpha=0.5)
axes[0].set_title(f"Pre-2008\nSpearman rho = {r_pre:.3f}")
axes[0].set_xlabel("log(GDP)")
axes[0].set_ylabel("Life Expectancy")

# Post-2008 scatter
axes[1].scatter(post["gdp_log"], post["life_expectancy_at_birth"], alpha=0.5)
axes[1].set_title(f"Post-2008\nSpearman rho = {r_post:.3f}")
axes[1].set_xlabel("log(GDP)")
axes[1].set_ylabel("Life Expectancy")

plt.tight_layout()
plt.show()
# Out:
# Pre-2008:
# rho: 0.422 p-value: 0.0 n: 9670
#
# Post-2008:
# rho: 0.45 p-value: 5.261268795374645e-162 n: 3253

# %% [markdown]
# ## Unexpected Pattern - GDP Bins

# %% [markdown]
# To explore unexpected patterns, GDP was divided into four groups (bins) using the log-transformed GDP values. The correlation between GDP and life expectancy was then calculated separately within each group. This revealed that the relationship is not perfectly linear: in lower GDP groups, increases in GDP are more strongly associated with improvements in life expectancy, while in higher GDP groups the relationship becomes weaker. This suggests diminishing returns of economic growth on health outcomes at higher income levels.

# %%
wb_df["gdp_bin"] = pd.cut(wb_df["gdp_log"], bins=4)

for b in wb_df["gdp_bin"].unique():
    df_b = wb_df[wb_df["gdp_bin"] == b]
    if len(df_b) > 10:
        r, p = spearmanr(df_b["gdp_log"], df_b["life_expectancy_at_birth"])
        print(f"\nGDP Bin: {b}")
        print("rho:", round(r, 3), "p-value:", p, "n:", len(df_b))
# Out:
# GDP Bin: (5.896, 9.614]
# rho: 0.132 p-value: 1.6019175758298412e-26 n: 6471
#
# GDP Bin: (9.614, 13.333]
# rho: 0.366 p-value: 2.943828846056186e-143 n: 4518
#
# GDP Bin: (2.162, 5.896]
# rho: 0.058 p-value: 0.03474364765875634 n: 1313
#
# GDP Bin: (13.333, 17.052]
# rho: 0.305 p-value: 7.310983800825947e-15 n: 621

# %% [markdown]
# ## The Story of GDP vs Life Expectancy

# %% [markdown]
# 1. What the data looks like
#
#    Before testing the relationship, the distributions of GDP and life expectancy were explored using histograms and boxplots. GDP showed a highly skewed distribution, with a small number of extremely rich countries. To reduce the impact of extreme values and improve interpretability, a log transformation was applied to GDP. Life expectancy showed a more balanced distribution with some variation across countries.
#
# 2. What the visualization shows
#
#    The scatter plot of log(GDP) against life expectancy shows a clear upward trend. Countries with higher economic output generally have higher life expectancy. The relationship is not perfectly linear, and the pattern becomes flatter among the richest countries, suggesting that economic growth has diminishing health returns at very high income levels.
#
# 3. What the statistics confirm
#
#    Both Pearson and Spearman correlation tests were computed. The results show a strong and statistically significant positive correlation between GDP and life expectancy. Spearman’s method was preferred due to skewness in GDP, as it is more robust to non-normal data. This confirms that economic strength and population health are strongly associated.
#
# 4. Differences across groups
#
#    When the data is split by income group, the relationship is strongest in low- and middle-income countries, where increases in GDP are clearly linked to longer life spans. In high-income countries, the correlation becomes weaker, indicating that other factors, such as healthcare efficiency and lifestyle, play a greater role once a country is already wealthy.
#
# 5. What this does not mean
#
#    Although GDP and life expectancy are strongly correlated, this does not prove causality. Higher GDP does not automatically cause better health. Factors such as education, governance, healthcare systems, and inequality also strongly influence life expectancy.
#
# 6. Main takeaway
#
#    The analysis shows that economic development and human well-being are strongly connected, especially in poorer countries. However, money alone is not enough — how resources are used matters more as countries become richer.

# %% [markdown]
# # Government effectiveness Vs Government expenditure on education

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr
import warnings
warnings.filterwarnings(action='ignore')
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# # Research Question

# %% [markdown]
# Is there a relationship between government effectiveness and government expenditure on education (% of GDP) across countries?

# %%
subset = wb_df[['gov_effectiveness_estimate', 'gov_exp_on_education_pct']].copy()
subset = subset.dropna()

subset.describe()
# Out:
#        gov_effectiveness_estimate  gov_exp_on_education_pct
# count                12923.000000              12923.000000
# mean                    -0.010661                  4.350833
# std                      0.987643                  2.082198
# min                     -2.440000                  0.130000
# 25%                     -0.740000                  3.050000
# 50%                     -0.160000                  4.070000
# 75%                      0.690000                  5.270000
# max                      2.470000                 44.330000

# %% [markdown]
# # Data Inspection : Distributions & Outliers

# %%
# Clean data (remove missing)
clean_wb = wb_df[["gov_effectiveness_estimate", "gov_exp_on_education_pct"]].dropna()

# Side-by-side histograms
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram: Government Effectiveness
sns.histplot(clean_wb["gov_effectiveness_estimate"], kde=True, ax=axes[0])
axes[0].set_title("Distribution of Government Effectiveness")
axes[0].set_xlabel("Gov Effectiveness Estimate")

# Histogram: Education Expenditure %
sns.histplot(clean_wb["gov_exp_on_education_pct"], kde=True, ax=axes[1])
axes[1].set_title("Distribution of Government Education Expenditure (%)")
axes[1].set_xlabel("Education Expenditure (% of GDP)")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Boxplot: Gov Effectiveness
sns.boxplot(y=clean_wb["gov_effectiveness_estimate"], ax=axes[0])
axes[0].set_title("Outliers in Government Effectiveness")

# Boxplot: Education Expenditure %
sns.boxplot(y=clean_wb["gov_exp_on_education_pct"], ax=axes[1])
axes[1].set_title("Outliers in Education Expenditure (%)")

plt.tight_layout()
plt.show()

# %%
clean_wb.skew()
# Out:
# gov_effectiveness_estimate    0.292991
# gov_exp_on_education_pct      2.322642
# dtype: float64

# %% [markdown]
# The histogram of government expenditure on education (% of GDP) shows a moderately right-skewed and slightly bimodal distribution, reflecting that most countries spend around 3–6% of GDP while a smaller group spends substantially more. Government effectiveness estimates are roughly symmetric, with most countries clustered around average values and only mild extremes. Because of the skewness in education expenditure, we applied a log transformation to make the distribution more symmetric and to linearize the relationship with government effectiveness

# %%
# Only apply log to positive values
edu_clean = clean_wb[clean_wb["gov_exp_on_education_pct"] > 0].copy()

edu_clean["edu_log"] = np.log(edu_clean["gov_exp_on_education_pct"])

sns.histplot(edu_clean["edu_log"], kde=True)
plt.title("Distribution of log(Education Expenditure %)")
plt.show()

# %%
sns.scatterplot(
    data=clean_wb,
    x="gov_effectiveness_estimate",
    y="gov_exp_on_education_pct",
    alpha=0.6
)
plt.title("Government Effectiveness vs Education Expenditure (%)")
plt.show()

# %%
sns.scatterplot(
    data=wb_df,
    x="gov_effectiveness_estimate",
    y="gov_exp_on_education_pct",
    hue="income_group",
    alpha=0.6
)
plt.title("Government Effectiveness vs Education Expenditure (%)")
plt.show()

# %% [markdown]
# # Correlation Tests

# %%
# 1. Clean the data
corr_df = wb_df[[
    "gov_effectiveness_estimate",
    "gov_exp_on_education_pct"
]].dropna()

# 2. Remove zero or negative education expenditure (if any)
corr_df = corr_df[corr_df["gov_exp_on_education_pct"] > 0]

# 3. Log-transform education expenditure
corr_df["edu_log"] = np.log(corr_df["gov_exp_on_education_pct"])

# 4. Assign variables
x = corr_df["gov_effectiveness_estimate"]
y = corr_df["edu_log"]

# 5. Run correlations
pearson_r, pearson_p = pearsonr(x, y)
spearman_r, spearman_p = spearmanr(x, y)

# 6. Print results
print("Pearson correlation:")
print("r =", round(pearson_r, 3), "p-value =", pearson_p)

print("\nSpearman correlation:")
print("rho =", round(spearman_r, 3), "p-value =", spearman_p)
# Out:
# Pearson correlation:
# r = 0.278 p-value = 1.0294851274127305e-227
#
# Spearman correlation:
# rho = 0.272 p-value = 3.2738581828019466e-218

# %% [markdown]
# # Analysis Report

# %% [markdown]
# A moderate positive relationship was found between government effectiveness and education expenditure. The Spearman correlation showed ρ = 0.272 (p < 0.001), and the Pearson correlation showed r = 0.278 (p < 0.001), indicating that countries with higher government effectiveness tend to allocate a larger share of GDP to education. While the association is statistically significant, the strength is moderate, suggesting that government effectiveness is an important, but not the only, factor influencing public investment in education.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Scatter plot
axes[0].scatter(x, y, alpha=0.6)
axes[0].set_xlabel("Government Effectiveness Estimate")
axes[0].set_ylabel("log(Education Expenditure % of GDP)")
axes[0].set_title("Government Effectiveness vs log(Education Expenditure)")

axes[0].text(
    0.05, 0.95,
    f"Pearson: {pearson_r:.3f} (p={pearson_p:.3e})\nSpearman: {spearman_r:.3f} (p={spearman_p:.3e})",
    transform=axes[0].transAxes,
    va="top",
    bbox=dict(boxstyle="round", facecolor="wheat", alpha=0.5)
)

# Histogram of y
axes[1].hist(y, bins=20, edgecolor='black', alpha=0.7, color='orange')
axes[1].set_xlabel("log(Education Expenditure % of GDP)")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Distribution of Education Expenditure (log)")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Statistical Test

# %% [markdown]
# We computed both Pearson and Spearman correlations between government effectiveness and log-transformed education expenditure. Pearson correlation is appropriate here because the log transformation reduces skewness in education spending, making the relationship with government effectiveness closer to linear. Spearman correlation is also reported as a robustness check because it is based on ranks and does not assume normality. Both tests indicate a statistically significant moderate positive association between government effectiveness and education expenditure.

# %% [markdown]
# # Group-Level Analysis (Income Groups)

# %%
# Log-transform education expenditure
wb_df["edu_log"] = np.log(wb_df["gov_exp_on_education_pct"])

# 1) Average by income group
group_means = wb_df.groupby("income_group")[
    ["gov_effectiveness_estimate", "edu_log"]
].mean().round(2)

print(group_means)

# 2) Bar plot: Average Government Effectiveness by Income Group
sns.barplot(
    data=group_means.reset_index(),
    x="income_group",
    y="gov_effectiveness_estimate"
)
plt.title("Average Government Effectiveness by Income Group")
plt.xlabel("Income Group")
plt.ylabel("Government Effectiveness Estimate")
plt.xticks(rotation=20)
plt.show()

# 3) Correlation within each income group
for g in wb_df["income_group"].dropna().unique():
    df_g = wb_df[wb_df["income_group"] == g]
    # Make sure to drop missing values
    df_g = df_g.dropna(subset=["gov_effectiveness_estimate", "edu_log"])
    r, p = spearmanr(df_g["gov_effectiveness_estimate"], df_g["edu_log"])
    print(f"\nIncome group: {g}")
    print("Spearman rho:", round(r, 3), " | p-value:", p, " | n:", len(df_g))
# Out:
#                      gov_effectiveness_estimate  edu_log
# income_group
# Low income                                -1.18     0.97
# Lower middle income                       -0.64     1.39
# Upper middle income                       -0.26     1.41
# High income                                0.99     1.45
# Income group: Low income
# Spearman rho: 0.416  | p-value: 6.715322086534254e-69  | n: 1625
#
# Income group: Upper middle income
# Spearman rho: 0.204  | p-value: 1.8642725057865678e-33  | n: 3408
#
# Income group: High income
# Spearman rho: 0.1  | p-value: 5.500381841184762e-12  | n: 4713
#
# Income group: Lower middle income
# Spearman rho: 0.296  | p-value: 3.419471338045813e-65  | n: 3177

# %% [markdown]
# # Temporal Analysis (Pre vs Post 2008)

# %%
# 1) Ensure edu_log exists and values are positive
wb_df = wb_df[wb_df["gov_exp_on_education_pct"] > 0].copy()
if "edu_log" not in wb_df.columns:
    wb_df["edu_log"] = np.log(wb_df["gov_exp_on_education_pct"])

# 2) Split into pre- and post-2008
pre = wb_df[wb_df["year"] < 2008]
post = wb_df[wb_df["year"] >= 2008]

# 3) Compute Spearman correlations
print("Pre-2008:")
r_pre, p_pre = spearmanr(pre["gov_effectiveness_estimate"], pre["edu_log"])
print("rho:", round(r_pre, 3), "p-value:", p_pre, "n:", len(pre))

print("\nPost-2008:")
r_post, p_post = spearmanr(post["gov_effectiveness_estimate"], post["edu_log"])
print("rho:", round(r_post, 3), "p-value:", p_post, "n:", len(post))

# 4) Plot side-by-side scatterplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Pre-2008 scatter
axes[0].scatter(pre["edu_log"], pre["gov_effectiveness_estimate"], alpha=0.5)
axes[0].set_title(f"Pre-2008\nSpearman rho = {r_pre:.3f}")
axes[0].set_xlabel("log(Education Expenditure % of GDP)")
axes[0].set_ylabel("Government Effectiveness Estimate")

# Post-2008 scatter
axes[1].scatter(post["edu_log"], post["gov_effectiveness_estimate"], alpha=0.5)
axes[1].set_title(f"Post-2008\nSpearman rho = {r_post:.3f}")
axes[1].set_xlabel("log(Education Expenditure % of GDP)")
axes[1].set_ylabel("Government Effectiveness Estimate")

plt.tight_layout()
plt.show()
# Out:
# Pre-2008:
# rho: 0.272 p-value: 3.3564997130473505e-164 n: 9670
#
# Post-2008:
# rho: 0.272 p-value: 2.840433624279818e-56 n: 3253

# %% [markdown]
# # Unexpected Pattern - GDP Bins

# %% [markdown]
# We divided countries into four groups based on log-transformed education expenditure and calculated Spearman correlations between government effectiveness and education spending within each group. This revealed a non-linear pattern: in lower expenditure bins, increases in spending are more strongly associated with higher government effectiveness, while in higher expenditure bins, the relationship weakens. This suggests diminishing returns: after a certain level of education spending, further increases are less closely tied to government effectiveness.

# %%
# 1) Ensure edu_log exists
wb_df = wb_df[wb_df["gov_exp_on_education_pct"] > 0].copy()
if "edu_log" not in wb_df.columns:
    wb_df["edu_log"] = np.log(wb_df["gov_exp_on_education_pct"])

# 2) Create bins for log education expenditure
wb_df["edu_bin"] = pd.cut(wb_df["edu_log"], bins=4)

# 3) Compute Spearman correlation within each bin
for b in wb_df["edu_bin"].unique():
    df_b = wb_df[wb_df["edu_bin"] == b]
    if len(df_b) > 10:  # skip very small bins
        r, p = spearmanr(df_b["edu_log"], df_b["gov_effectiveness_estimate"])
        print(f"\nEducation Expenditure Bin: {b}")
        print("Spearman rho:", round(r, 3), "p-value:", p, "n:", len(df_b))
# Out:
# Education Expenditure Bin: (0.876, 2.334]
# Spearman rho: 0.176 p-value: 3.369076328768632e-76 n: 10848
#
# Education Expenditure Bin: (-0.582, 0.876]
# Spearman rho: 0.139 p-value: 6.2153632415671564e-09 n: 1740
#
# Education Expenditure Bin: (2.334, 3.792]
# Spearman rho: 0.249 p-value: 3.1109537705246854e-05 n: 273
#
# Education Expenditure Bin: (-2.046, -0.582]
# Spearman rho: 0.309 p-value: 0.01447068008446996 n: 62

# %% [markdown]
# What the data looks like
#
# Before testing the relationship, the distributions of government effectiveness and education expenditure were explored using histograms and boxplots. Government effectiveness scores ranged from negative to positive values, reflecting weaker to stronger governance across countries. Education expenditure (as a percentage of GDP) was right-skewed, with some countries spending much more than others. To reduce skewness and improve interpretability, a log transformation was applied to education expenditure.
#
# What the visualization shows
#
# The scatter plot of log-transformed education expenditure against government effectiveness shows an upward trend. Countries with higher government effectiveness tend to spend more on education. The relationship is not perfectly linear, and the pattern becomes flatter at higher expenditure levels, suggesting diminishing returns — once a country is already spending a lot on education, further increases are less strongly associated with stronger governance.
#
# What the statistics confirm
#
# Both Pearson and Spearman correlation tests were computed. The results show a moderate and statistically significant positive correlation between government effectiveness and education expenditure (Pearson r = 0.278, Spearman ρ = 0.272, p < 0.001). Spearman’s method is particularly useful here as it is robust to non-normal distributions. This confirms that better governance is associated with higher investment in education.
#
# Differences across groups
#
# When the data is split by income group, the relationship is strongest in low-income countries (ρ = 0.416), moderate in lower-middle and upper-middle income countries, and weakest in high-income countries (ρ = 0.100). This indicates that improvements in governance are more closely linked to higher education spending in poorer countries, whereas in richer countries, education expenditure is relatively high regardless of governance effectiveness.
#
# What this does not mean
#
# Although government effectiveness and education expenditure are positively correlated, this does not prove causation. Higher governance scores do not automatically cause higher spending. Other factors, such as GDP, political priorities, population size, and historical policy decisions, may also influence education expenditure.
#
# Main takeaway
#
# The analysis shows that governance quality and investment in education are positively connected, especially in lower-income countries. However, improving governance alone is not enough — how resources are allocated and used also matters, particularly in higher-income countries.
