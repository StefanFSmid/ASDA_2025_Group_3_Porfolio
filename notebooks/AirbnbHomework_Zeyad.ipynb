# %% [markdown]
# ## Data Loading

# %%
import pandas as pd

# Load the Excel file from the given URL
url = 'https://docs.google.com/spreadsheets/d/1ecopK6oyyb4d_7-QLrCr8YlgFrCetHU7-VQfnYej7JY/export?format=xlsx'
airbnb = pd.ExcelFile(url)

# %%
# Merge all sheets into a single DataFrame with an additional column for sheet names
merged_airbnb= pd.concat(
    [airbnb.parse(sheet).assign(sheet_name=sheet) for sheet in airbnb.sheet_names],
    ignore_index=True
)

# %% [markdown]
# ## 1)Dataset Overview

# %%
#Sample of the merged DataFrame
merged_airbnb.head()
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0                2              False      1    0                  10  ...
# 1                4              False      0    0                   8  ...
# 2                2              False      0    1                   9  ...
# 3                4              False      0    1                   9  ...
# 4                2               True      0    0                  10  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0         1  5.022964    2.539380   78.690379         4.166708   98.253896
# 1         1  0.488389    0.239404  631.176378        33.421209  837.280757
# 2         1  5.748312    3.651621   75.275877         3.985908   95.386955
# 3         2  0.384862    0.439876  493.272534        26.119108  875.033098
# 4         1  0.544738    0.318693  552.830324        29.272733  815.305740
#
#    rest_index_norm      lng       lat          sheet_name
# 0         6.846473  4.90569  52.41772  amsterdam_weekdays
# 1        58.342928  4.90005  52.37432  amsterdam_weekdays
# 2         6.646700  4.97512  52.36103  amsterdam_weekdays
# 3        60.973565  4.89417  52.37663  amsterdam_weekdays
# 4        56.811677  4.90051  52.37508  amsterdam_weekdays
#
# [5 rows x 21 columns]

# %%
#Information about the DataFrame
merged_airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51707 entries, 0 to 51706
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  51707 non-null  int64
#  1   realSum                     51707 non-null  float64
#  2   room_type                   51707 non-null  object
#  3   room_shared                 51707 non-null  bool
#  4   room_private                51707 non-null  bool
#  5   person_capacity             51707 non-null  int64
#  6   host_is_superhost           51707 non-null  bool
#  7   multi                       51707 non-null  int64
#  8   biz                         51707 non-null  int64
#  9   cleanliness_rating          51707 non-null  int64
#  10  guest_satisfaction_overall  51707 non-null  int64
#  11  bedrooms                    51707 non-null  int64
#  12  dist                        51707 non-null  float64
#  13  metro_dist                  51707 non-null  float64
#  14  attr_index                  51707 non-null  float64
#  15  attr_index_norm             51707 non-null  float64
#  16  rest_index                  51707 non-null  float64
#  17  rest_index_norm             51707 non-null  float64
#  18  lng                         51707 non-null  float64
#  19  lat                         51707 non-null  float64
#  20  sheet_name                  51707 non-null  object
# dtypes: bool(3), float64(9), int64(7), object(2)
# memory usage: 7.2+ MB

# %%
#Number of rows and Columns
merged_airbnb.shape
# Out:
# (51707, 21)

# %% [markdown]
# ## 2)Dataset Structure

# %%
Structure = pd.DataFrame({
    'Column name': merged_airbnb.columns,
    'Data type': merged_airbnb.dtypes.values,
    'Non-null count': merged_airbnb.notnull().sum().values,
    'Unique values': [merged_airbnb[col].nunique() for col in merged_airbnb.columns],
    'Example values': [merged_airbnb[col].dropna().unique()[:3] for col in merged_airbnb.columns]
})

Structure
# Out:
#                    Column name Data type  Non-null count  Unique values  \
# 0                   Unnamed: 0     int64           51707           5379
# 1                      realSum   float64           51707          10497
# 2                    room_type    object           51707              3
# 3                  room_shared      bool           51707              2
# 4                 room_private      bool           51707              2
# 5              person_capacity     int64           51707              5
# 6            host_is_superhost      bool           51707              2
# 7                        multi     int64           51707              2
# 8                          biz     int64           51707              2
# 9           cleanliness_rating     int64           51707              9
# 10  guest_satisfaction_overall     int64           51707             53
# 11                    bedrooms     int64           51707             10
# 12                        dist   float64           51707          51707
# 13                  metro_dist   float64           51707          51707
# 14                  attr_index   float64           51707          51707
# 15             attr_index_norm   float64           51707          51688
# 16                  rest_index   float64           51707          51707
# 17             rest_index_norm   float64           51707          51688
# 18                         lng   float64           51707          23600
# 19                         lat   float64           51707          21484
# 20                  sheet_name    object           51707             20
#
#                                        Example values
# 0                                           [0, 1, 2]
# 1   [194.033698122934, 344.245776017622, 264.10142...
# 2        [Private room, Entire home/apt, Shared room]
# 3                                       [False, True]
# 4                                       [True, False]
# 5                                           [2, 4, 3]
# 6                                       [False, True]
# 7                                              [1, 0]
# 8                                              [0, 1]
# 9                                          [10, 8, 9]
# 10                                       [93, 85, 87]
# 11                                          [1, 2, 3]
# 12  [5.02296379808829, 0.488389288828983, 5.748311...
# 13  [2.53938000259449, 0.239403922834986, 3.651621...
# 14  [78.6903792719031, 631.176378250396, 75.275876...
# 15  [4.16670786849074, 33.4212086152754, 3.9859076...
# 16  [98.2538958700993, 837.280756742269, 95.386954...
# 17  [6.84647282420001, 58.342927743449, 6.64670025...
# 18               [4.90569, 4.90005, 4.97511999999999]
# 19                     [52.41772, 52.37432, 52.36103]
# 20  [amsterdam_weekdays, amsterdam_weekends, athen...

# %% [markdown]
# ## 3) Data Cleaning

# %%
merged_airbnb['City'] = merged_airbnb['sheet_name'].str.split('_').str[0].str.capitalize()
merged_airbnb
# Out:
#        Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0               0  194.033698     Private room        False          True
# 1               1  344.245776     Private room        False          True
# 2               2  264.101422     Private room        False          True
# 3               3  433.529398     Private room        False          True
# 4               4  485.552926     Private room        False          True
# ...           ...         ...              ...          ...           ...
# 51702        1794  715.938574  Entire home/apt        False         False
# 51703        1795  304.793960  Entire home/apt        False         False
# 51704        1796  637.168969  Entire home/apt        False         False
# 51705        1797  301.054157     Private room        False          True
# 51706        1798  133.230489     Private room        False          True
#
#        person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0                    2              False      1    0                  10
# 1                    4              False      0    0                   8
# 2                    2              False      0    1                   9
# 3                    4              False      0    1                   9
# 4                    2               True      0    0                  10
# ...                ...                ...    ...  ...                 ...
# 51702                6              False      0    1                  10
# 51703                2              False      0    0                   8
# 51704                2              False      0    0                  10
# 51705                2              False      0    0                  10
# 51706                4               True      1    0                  10
#
#        ...      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0      ...  5.022964    2.539380   78.690379         4.166708   98.253896
# 1      ...  0.488389    0.239404  631.176378        33.421209  837.280757
# 2      ...  5.748312    3.651621   75.275877         3.985908   95.386955
# 3      ...  0.384862    0.439876  493.272534        26.119108  875.033098
# 4      ...  0.544738    0.318693  552.830324        29.272733  815.305740
# ...    ...       ...         ...         ...              ...         ...
# 51702  ...  0.530181    0.135447  219.402478        15.712158  438.756874
# 51703  ...  0.810205    0.100839  204.970121        14.678608  342.182813
# 51704  ...  0.994051    0.202539  169.073402        12.107921  282.296424
# 51705  ...  3.044100    0.287435  109.236574         7.822803  158.563398
# 51706  ...  1.263932    0.480903  150.450381        10.774264  225.247293
#
#        rest_index_norm       lng       lat          sheet_name       City
# 0             6.846473   4.90569  52.41772  amsterdam_weekdays  Amsterdam
# 1            58.342928   4.90005  52.37432  amsterdam_weekdays  Amsterdam
# 2             6.646700   4.97512  52.36103  amsterdam_weekdays  Amsterdam
# 3            60.973565   4.89417  52.37663  amsterdam_weekdays  Amsterdam
# 4            56.811677   4.90051  52.37508  amsterdam_weekdays  Amsterdam
# ...                ...       ...       ...                 ...        ...
# 51702        10.604584  16.37940  48.21136     vienna_weekends     Vienna
# 51703         8.270427  16.38070  48.20296     vienna_weekends     Vienna
# 51704         6.822996  16.38568  48.20460     vienna_weekends     Vienna
# 51705         3.832416  16.34100  48.19200     vienna_weekends     Vienna
# 51706         5.444140  16.39066  48.20811     vienna_weekends     Vienna
#
# [51707 rows x 22 columns]

# %%
city_to_country = {
    'Amsterdam': 'Netherlands',
    'Athens': 'Greece',
    'Berlin': 'Germany',
    'Barcelona': 'Spain',
    'Budapest': 'Hungary',
    'Lisbon': 'Portugal',
    'London': 'United Kingdom',
    'Paris': 'France',
    'Rome': 'Italy',
    'Vienna': 'Austria'
}
merged_airbnb['Country'] = merged_airbnb['City'].map(city_to_country)
merged_airbnb['Weekday/Weekend'] = merged_airbnb['sheet_name'].str.split('_').str[-1].str.capitalize().str.rstrip('s')
merged_airbnb
# Out:
#        Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0               0  194.033698     Private room        False          True
# 1               1  344.245776     Private room        False          True
# 2               2  264.101422     Private room        False          True
# 3               3  433.529398     Private room        False          True
# 4               4  485.552926     Private room        False          True
# ...           ...         ...              ...          ...           ...
# 51702        1794  715.938574  Entire home/apt        False         False
# 51703        1795  304.793960  Entire home/apt        False         False
# 51704        1796  637.168969  Entire home/apt        False         False
# 51705        1797  301.054157     Private room        False          True
# 51706        1798  133.230489     Private room        False          True
#
#        person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0                    2              False      1    0                  10
# 1                    4              False      0    0                   8
# 2                    2              False      0    1                   9
# 3                    4              False      0    1                   9
# 4                    2               True      0    0                  10
# ...                ...                ...    ...  ...                 ...
# 51702                6              False      0    1                  10
# 51703                2              False      0    0                   8
# 51704                2              False      0    0                  10
# 51705                2              False      0    0                  10
# 51706                4               True      1    0                  10
#
#        ...  attr_index  attr_index_norm  rest_index  rest_index_norm  \
# 0      ...   78.690379         4.166708   98.253896         6.846473
# 1      ...  631.176378        33.421209  837.280757        58.342928
# 2      ...   75.275877         3.985908   95.386955         6.646700
# 3      ...  493.272534        26.119108  875.033098        60.973565
# 4      ...  552.830324        29.272733  815.305740        56.811677
# ...    ...         ...              ...         ...              ...
# 51702  ...  219.402478        15.712158  438.756874        10.604584
# 51703  ...  204.970121        14.678608  342.182813         8.270427
# 51704  ...  169.073402        12.107921  282.296424         6.822996
# 51705  ...  109.236574         7.822803  158.563398         3.832416
# 51706  ...  150.450381        10.774264  225.247293         5.444140
#
#             lng       lat          sheet_name       City      Country  \
# 0       4.90569  52.41772  amsterdam_weekdays  Amsterdam  Netherlands
# 1       4.90005  52.37432  amsterdam_weekdays  Amsterdam  Netherlands
# 2       4.97512  52.36103  amsterdam_weekdays  Amsterdam  Netherlands
# 3       4.89417  52.37663  amsterdam_weekdays  Amsterdam  Netherlands
# 4       4.90051  52.37508  amsterdam_weekdays  Amsterdam  Netherlands
# ...         ...       ...                 ...        ...          ...
# 51702  16.37940  48.21136     vienna_weekends     Vienna      Austria
# 51703  16.38070  48.20296     vienna_weekends     Vienna      Austria
# 51704  16.38568  48.20460     vienna_weekends     Vienna      Austria
# 51705  16.34100  48.19200     vienna_weekends     Vienna      Austria
# 51706  16.39066  48.20811     vienna_weekends     Vienna      Austria
#
#        Weekday/Weekend
# 0              Weekday
# 1              Weekday
# 2              Weekday
# 3              Weekday
# 4              Weekday
# ...                ...
# 51702          Weekend
# 51703          Weekend
# 51704          Weekend
# 51705          Weekend
# 51706          Weekend
#
# [51707 rows x 24 columns]

# %%
merged_airbnb.rename(columns={'realSum': 'Price'}, inplace=True)
merged_airbnb.drop(columns='Unnamed: 0',inplace=True)
merged_airbnb.head()
# Out:
#         Price     room_type  room_shared  room_private  person_capacity  \
# 0  194.033698  Private room        False          True                2
# 1  344.245776  Private room        False          True                4
# 2  264.101422  Private room        False          True                2
# 3  433.529398  Private room        False          True                4
# 4  485.552926  Private room        False          True                2
#
#    host_is_superhost  multi  biz  cleanliness_rating  \
# 0              False      1    0                  10
# 1              False      0    0                   8
# 2              False      0    1                   9
# 3              False      0    1                   9
# 4               True      0    0                  10
#
#    guest_satisfaction_overall  ...  attr_index  attr_index_norm  rest_index  \
# 0                          93  ...   78.690379         4.166708   98.253896
# 1                          85  ...  631.176378        33.421209  837.280757
# 2                          87  ...   75.275877         3.985908   95.386955
# 3                          90  ...  493.272534        26.119108  875.033098
# 4                          98  ...  552.830324        29.272733  815.305740
#
#    rest_index_norm      lng       lat          sheet_name       City  \
# 0         6.846473  4.90569  52.41772  amsterdam_weekdays  Amsterdam
# 1        58.342928  4.90005  52.37432  amsterdam_weekdays  Amsterdam
# 2         6.646700  4.97512  52.36103  amsterdam_weekdays  Amsterdam
# 3        60.973565  4.89417  52.37663  amsterdam_weekdays  Amsterdam
# 4        56.811677  4.90051  52.37508  amsterdam_weekdays  Amsterdam
#
#        Country Weekday/Weekend
# 0  Netherlands         Weekday
# 1  Netherlands         Weekday
# 2  Netherlands         Weekday
# 3  Netherlands         Weekday
# 4  Netherlands         Weekday
#
# [5 rows x 23 columns]

# %%
def host_type(row):
    if row['multi']:
        return 'Two to Four'
    elif row['biz']:
        return 'More than Four'
    else:
        return 'Only One'
merged_airbnb['Host_listings'] = merged_airbnb.apply(host_type, axis=1)
merged_airbnb = merged_airbnb.drop(columns=['multi', 'biz'])
host_list = merged_airbnb.pop('Host_listings')
merged_airbnb.insert(5,'Host_listings', host_list)
merged_airbnb.head()
# Out:
#         Price     room_type  room_shared  room_private  person_capacity  \
# 0  194.033698  Private room        False          True                2
# 1  344.245776  Private room        False          True                4
# 2  264.101422  Private room        False          True                2
# 3  433.529398  Private room        False          True                4
# 4  485.552926  Private room        False          True                2
#
#     Host_listings  host_is_superhost  cleanliness_rating  \
# 0     Two to Four              False                  10
# 1        Only One              False                   8
# 2  More than Four              False                   9
# 3  More than Four              False                   9
# 4        Only One               True                  10
#
#    guest_satisfaction_overall  bedrooms  ...  attr_index  attr_index_norm  \
# 0                          93         1  ...   78.690379         4.166708
# 1                          85         1  ...  631.176378        33.421209
# 2                          87         1  ...   75.275877         3.985908
# 3                          90         2  ...  493.272534        26.119108
# 4                          98         1  ...  552.830324        29.272733
#
#    rest_index  rest_index_norm      lng       lat          sheet_name  \
# 0   98.253896         6.846473  4.90569  52.41772  amsterdam_weekdays
# 1  837.280757        58.342928  4.90005  52.37432  amsterdam_weekdays
# 2   95.386955         6.646700  4.97512  52.36103  amsterdam_weekdays
# 3  875.033098        60.973565  4.89417  52.37663  amsterdam_weekdays
# 4  815.305740        56.811677  4.90051  52.37508  amsterdam_weekdays
#
#         City      Country Weekday/Weekend
# 0  Amsterdam  Netherlands         Weekday
# 1  Amsterdam  Netherlands         Weekday
# 2  Amsterdam  Netherlands         Weekday
# 3  Amsterdam  Netherlands         Weekday
# 4  Amsterdam  Netherlands         Weekday
#
# [5 rows x 22 columns]

# %%
# Move multiple columns at beginning
cols = list(merged_airbnb.columns)

cols_to_move = ['Country', 'City', 'Weekday/Weekend']

# Remove them
for col in cols_to_move:
    cols.remove(col)

# Insert them starting at position 1
for i, col in enumerate(cols_to_move):
    cols.insert(i, col)

# Reorder dataframe
merged_airbnb = merged_airbnb[cols]


merged_airbnb = merged_airbnb.drop('sheet_name', axis=1)

merged_airbnb.head()
# Out:
#        Country       City Weekday/Weekend       Price     room_type  \
# 0  Netherlands  Amsterdam         Weekday  194.033698  Private room
# 1  Netherlands  Amsterdam         Weekday  344.245776  Private room
# 2  Netherlands  Amsterdam         Weekday  264.101422  Private room
# 3  Netherlands  Amsterdam         Weekday  433.529398  Private room
# 4  Netherlands  Amsterdam         Weekday  485.552926  Private room
#
#    room_shared  room_private  person_capacity   Host_listings  \
# 0        False          True                2     Two to Four
# 1        False          True                4        Only One
# 2        False          True                2  More than Four
# 3        False          True                4  More than Four
# 4        False          True                2        Only One
#
#    host_is_superhost  ...  guest_satisfaction_overall  bedrooms      dist  \
# 0              False  ...                          93         1  5.022964
# 1              False  ...                          85         1  0.488389
# 2              False  ...                          87         1  5.748312
# 3              False  ...                          90         2  0.384862
# 4               True  ...                          98         1  0.544738
#
#    metro_dist  attr_index  attr_index_norm  rest_index  rest_index_norm  \
# 0    2.539380   78.690379         4.166708   98.253896         6.846473
# 1    0.239404  631.176378        33.421209  837.280757        58.342928
# 2    3.651621   75.275877         3.985908   95.386955         6.646700
# 3    0.439876  493.272534        26.119108  875.033098        60.973565
# 4    0.318693  552.830324        29.272733  815.305740        56.811677
#
#        lng       lat
# 0  4.90569  52.41772
# 1  4.90005  52.37432
# 2  4.97512  52.36103
# 3  4.89417  52.37663
# 4  4.90051  52.37508
#
# [5 rows x 21 columns]

# %%
#Round decimals

for col in merged_airbnb.select_dtypes(include=['float', 'int']).columns:
    if merged_airbnb[col].dtype == 'float':
        merged_airbnb[col] = merged_airbnb[col].round(2)
    else:
        merged_airbnb[col] = merged_airbnb[col].round(0)


merged_airbnb.head()
# Out:
#        Country       City Weekday/Weekend   Price     room_type  room_shared  \
# 0  Netherlands  Amsterdam         Weekday  194.03  Private room        False
# 1  Netherlands  Amsterdam         Weekday  344.25  Private room        False
# 2  Netherlands  Amsterdam         Weekday  264.10  Private room        False
# 3  Netherlands  Amsterdam         Weekday  433.53  Private room        False
# 4  Netherlands  Amsterdam         Weekday  485.55  Private room        False
#
#    room_private  person_capacity   Host_listings  host_is_superhost  ...  \
# 0          True                2     Two to Four              False  ...
# 1          True                4        Only One              False  ...
# 2          True                2  More than Four              False  ...
# 3          True                4  More than Four              False  ...
# 4          True                2        Only One               True  ...
#
#    guest_satisfaction_overall  bedrooms  dist  metro_dist  attr_index  \
# 0                          93         1  5.02        2.54       78.69
# 1                          85         1  0.49        0.24      631.18
# 2                          87         1  5.75        3.65       75.28
# 3                          90         2  0.38        0.44      493.27
# 4                          98         1  0.54        0.32      552.83
#
#    attr_index_norm  rest_index  rest_index_norm   lng    lat
# 0             4.17       98.25             6.85  4.91  52.42
# 1            33.42      837.28            58.34  4.90  52.37
# 2             3.99       95.39             6.65  4.98  52.36
# 3            26.12      875.03            60.97  4.89  52.38
# 4            29.27      815.31            56.81  4.90  52.38
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 4) Descriptive Statistics

# %%
#Descriptive statistics of the DataFrame
merged_airbnb.describe().round(2)
# Out:
#           Price  person_capacity  cleanliness_rating  \
# count  51707.00         51707.00            51707.00
# mean     279.88             3.16                9.39
# std      327.95             1.30                0.95
# min       34.78             2.00                2.00
# 25%      148.75             2.00                9.00
# 50%      211.34             3.00               10.00
# 75%      319.69             4.00               10.00
# max    18545.45             6.00               10.00
#
#        guest_satisfaction_overall  bedrooms      dist  metro_dist  attr_index  \
# count                    51707.00  51707.00  51707.00    51707.00    51707.00
# mean                        92.63      1.16      3.19        0.68      294.20
# std                          8.95      0.63      2.39        0.86      224.75
# min                         20.00      0.00      0.02        0.00       15.15
# 25%                         90.00      1.00      1.45        0.25      136.80
# 50%                         95.00      1.00      2.61        0.41      234.33
# 75%                         99.00      1.00      4.26        0.74      385.76
# max                        100.00     10.00     25.28       14.27     4513.56
#
#        attr_index_norm  rest_index  rest_index_norm       lng       lat
# count         51707.00    51707.00         51707.00  51707.00  51707.00
# mean             13.42      626.86            22.79      7.43     45.67
# std               9.81      497.92            17.80      9.80      5.25
# min               0.93       19.58             0.59     -9.23     37.95
# 25%               6.38      250.85             8.75     -0.07     41.40
# 50%              11.47      522.05            17.54      4.87     47.51
# 75%              17.42      832.63            32.97     13.52     51.47
# max             100.00     6696.16           100.00     23.79     52.64

# %%
#Category Columns
category_columns = merged_airbnb.select_dtypes(include=['object']).columns
category_columns
# Out:
# Index(['Country', 'City', 'Weekday/Weekend', 'room_type', 'Host_listings'], dtype='object')

# %%
cat_summary = {}

for col in category_columns:
    vc = merged_airbnb[col].value_counts(dropna=False)
    cat_summary[col] = [
        merged_airbnb[col].count(),
        merged_airbnb[col].nunique(dropna=False),
        vc.idxmax(),
        vc.max(),
        vc.idxmin(),
        vc.min()
    ]

cat_summary_table = pd.DataFrame(
    cat_summary,
    index=[
        'Count',
        'Number of unique values',
        'Most frequent value',
        'Most frequent value (frequency)',
        'Least frequent value',
        'Least frequent value (frequency)'
    ]
)

cat_summary_table
# Out:
#                                          Country       City Weekday/Weekend  \
# Count                                      51707      51707           51707
# Number of unique values                       10         10               2
# Most frequent value               United Kingdom     London         Weekend
# Most frequent value (frequency)             9993       9993           26207
# Least frequent value                 Netherlands  Amsterdam         Weekday
# Least frequent value (frequency)            2080       2080           25500
#
#                                         room_type Host_listings
# Count                                       51707         51707
# Number of unique values                         3             3
# Most frequent value               Entire home/apt      Only One
# Most frequent value (frequency)             32648         18534
# Least frequent value                  Shared room   Two to Four
# Least frequent value (frequency)              366         15065
